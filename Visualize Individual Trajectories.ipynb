# %% [markdown]
# <hr>
#
# # Visualize Individual Trajectories
# author, date = p.caldas@fct.unl.pt, May 2021 Version
#
# <hr>

# %%
# import main function from src folder --> aka where the magic happens
from src.visualize_multiple_tracks import show_tracks

# %%
# select xml file containing trajectories to plot --> 25 tracks are selected randomly from all tracks

xml_file = 'data/FtsA R286W_Exp4_114ms_p3.xml'

show_tracks(xml_file, filter_tracks = 30, color = 'green')
